# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("placement.csv")

# %%
df.sample(5)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 3            3   7.4  132.0          1
# 37          37   8.1  149.0          1
# 52          52   7.0  175.0          1
# 59          59   4.8  112.0          0
# 15          15   5.1  176.0          0

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'cgpa', 'iq', 'placement', 'cgpa_zscore'], dtype='object')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df["cgpa"])
plt.subplot(1,2,2)
sns.distplot(df["placement"])
plt.show()
# Out:
# C:\Users\bhard\AppData\Local\Temp\ipykernel_26728\3017414907.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["cgpa"])
# C:\Users\bhard\AppData\Local\Temp\ipykernel_26728\3017414907.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["placement"])

# %%
df.shape
# Out:
# (100, 5)

# %%
print("mean of the value",df["cgpa"].mean())
print("mean of the value",df["cgpa"].std())
print("mean of the value",df["cgpa"].min())
print("mean of the value",df["cgpa"].max())
# Out:
# mean of the value 5.9910000000000005
# mean of the value 1.1436336737775692
# mean of the value 3.3
# mean of the value 8.5

# %%
print("upper value",df["cgpa"].mean()+3*df["cgpa"].std())
print("lower value",df["cgpa"].mean()-3*df["cgpa"].std())
# Out:
# upper value 9.421901021332708
# lower value 2.560098978667293

# %%
#finding the outliers
df[(df["cgpa"]>8.8)|(df["cgpa"]<5.11)]
# Out:
#     Unnamed: 0  cgpa     iq  placement  cgpa_zscore
# 7            7   5.0   63.0          0    -0.238566
# 9            9   5.1   66.0          0    -0.138566
# 15          15   5.1  176.0          0    -0.138566
# 17          17   3.3  183.0          0    -1.938566
# 18          18   4.0  100.0          0    -1.238566
# 22          22   4.9  120.0          0    -0.338566
# 23          23   4.7   87.0          0    -0.538566
# 24          24   4.7  121.0          0    -0.538566
# 25          25   5.0   91.0          0    -0.238566
# 31          31   3.9  109.0          0    -1.338566
# 34          34   4.8  163.0          0    -0.438566
# 39          39   4.6  146.0          0    -0.638566
# 40          40   4.9  134.0          0    -0.338566
# 50          50   3.5  233.0          0    -1.738566
# 51          51   4.8  141.0          0    -0.438566
# 59          59   4.8  112.0          0    -0.438566
# 67          67   5.0  118.0          0    -0.238566
# ...

# %%
new_df=df[(df["cgpa"]<8.80)&(df["cgpa"]>5.11)]
new_df
# Out:
#     Unnamed: 0  cgpa     iq  placement  cgpa_zscore
# 0            0   6.8  123.0          1     1.561434
# 1            1   5.9  106.0          0     0.661434
# 2            2   5.3  121.0          0     0.061434
# 3            3   7.4  132.0          1     2.161434
# 4            4   5.8  142.0          0     0.561434
# ..         ...   ...    ...        ...          ...
# 92          92   5.2  110.0          0    -0.038566
# 93          93   6.8  112.0          1     1.561434
# 97          97   6.7  182.0          1     1.461434
# 98          98   6.3  103.0          1     1.061434
# 99          99   6.2  113.0          1     0.961434
#
# [72 rows x 5 columns]

# %%
df["cgpa_zscore"]=(df["cgpa"]-df["cgpa"].mean()/df["cgpa"].std())
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement  cgpa_zscore
# 0           0   6.8  123.0          1     1.561434
# 1           1   5.9  106.0          0     0.661434
# 2           2   5.3  121.0          0     0.061434
# 3           3   7.4  132.0          1     2.161434
# 4           4   5.8  142.0          0     0.561434

# %%
df.shape
# Out:
# (100, 4)
